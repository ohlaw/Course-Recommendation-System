# %% [markdown]
# <div class="alert alert-info">
#
# ## Project Description
#
# As a data analyst, the objective of this project is to analyze and explore Udemy dataset containing information about various online courses. The dataset includes details such as course titles, pricing, enrollment statistics, instructor information, and other relevant attributes. The project aims to gain insights into the online course market, identify popular trends, and understand factors influencing course success.
#
#
#
#
# <br>
#     <b>Data Source:</b> <a href="https://www.kaggle.com/datasets/hossaingh/udemy-courses?resource=download&select=Course_info.csv">Kaggle<a/>
# <br>
#
# <b>Dataset description</b>
# `course_info.csv` — the calendar of marketing events for 2020
# * `id`: A unique identifier for each course.
# * `title`: The title or name of the course.
# * `is_paid`: A boolean (True/False) indicating whether the course is paid or free.
# * `price`: The price of the course. If the course is free, the price will be 0.
# * `headline`: A brief description or headline of the course content.
# * `num_subscribers`: The number of subscribers or students enrolled in the course.
# * `avg_rating`: The average rating given by students who have taken the course.
# * `num_reviews`: The number of reviews the course has received.
# * `num_comments`: The number of comments posted by students or users about the course.
# * `num_lectures`: The number of lectures or lessons in the course.
# * `content_length_min`: The total length of the course content in minutes.
# * `published_time`: The date and time when the course was initially published.
# * `last_update_date`: The date when the course was last updated.
# * `category`: The broad category to which the course belongs (e.g., Lifestyle, Business, Design, etc.).
# * `subcategory`: The subcategory within the broader category (e.g., Food & Beverage, Entrepreneurship, Web Design, etc.).
# * `topic`: The specific topic or subject of the course.
# * `language`: The language in which the course is conducted.
# * `course_url`: The URL or link to access the course.
# * `instructor_name`: The name of the course instructor.
# * `instructor_url`: The URL or link to the instructor's profile.
# </div>
#
# ---
#
# ## Table of Contents
#
# <a href="#Step-1.-Download-and-prepare-data-for-analysis">Step 1. Download and prepare data for analysis<a/>
# * <a href="#Load-Libraries">Load libraries<a/>
# * <a href="#Load-Datasets">Load datasets<a/>
# * <a href="#Missing-Values-and-Duplicates">Missing values and duplicates<a/>

# %% [markdown]
# ### Load Libraries

# %%
# import libraries
import pandas as pd
import numpy as np
import re
import streamlit as st
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity,linear_kernel
import neattext.functions as nfx
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/scipy/__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %% [markdown]
# ### Load Datasets

# %%
# load dataset
df = pd.read_csv('course_info.csv')
display(df.head(20))
# Out:
#         id                                              title  is_paid  \
# 0   4715.0             Online Vegan Vegetarian Cooking School     True
# 1   1769.0         The Lean Startup Talk at Stanford E-Corner    False
# 2   5664.0  How To Become a Vegan, Vegetarian, or Flexitarian     True
# 3   7723.0                               How to Train a Puppy     True
# 4   8157.0                      Web Design from the Ground Up     True
# 5   8139.0           14-Day Yoga Detox and Empowerment Course     True
# 6   2762.0  Simple Strategy for Swing Trading the Stock Ma...     True
# 7   8082.0                     Ruby Programming for Beginners     True
# 8   8075.0  How to Create an Awesome Demo Video for Your B...     True
# 9   8069.0                                   Curso SEO Online     True
# 10  8318.0              Navigating the MBA Admissions Process     True
# 11  8422.0  Kundalini Yoga to Heal Stress and Anxiety by V...     True
# 12  8416.0  Beginners - How To Create iPhone And iPad Apps...     True
# 13  8420.0  CCNP ROUTE 300-101 Video Boot Camp With Chris ...     True
# 14  8324.0                           Javascript for Beginners     True
# 15  8467.0                                   The Lean Startup     True
# 16  8471.0                       Healthy Cooking Fundamentals     True
# 17  8319.0                 Git Basics: In Theory and Practice     True
# 18  8410.0                            Intro to Adobe InDesign     True
# 19  8629.0  Chemistry Funda ( From Basics to Pre universit...     True
#
#      price                                           headline  \
# 0    24.99  Learn to cook delicious vegan recipes. Filmed ...
# 1     0.00  Debunking Myths of Entrepreneurship A startup ...
# 2    19.99  Get the tools you need for a lifestyle change ...
# 3   199.99  Train your puppy the right way with Dr. Ian Du...
# 4   159.99  Learn web design online: Everything you need t...
# 5    29.99  Lose weight, get healthier and fit on all leve...
# 6    39.99  Use my favorite Technical Indicator and the Tr...
# 7    74.99      Learn Ruby Programming the fast and easy way!
# 8   149.99  You don't need to spend $10K in order to have ...
# 9    99.99  Curso SEO práctico. Aprenda a posicionar su si...
# 10   49.99  MBA Admission: The Complete Course on How to G...
# 11   49.99  Kundalini Yoga is highly effective simple yoga...
# 12   49.99  Learn How To Create IOS Apps And Never Do A Ha...
# 13   19.99  Pass The CCNP ROUTE 300-101 Exam With Chris Br...
# 14   19.99  Learn javascript online and supercharge your w...
# 15   39.99  Learn how to apply the method that is transfor...
# 16   29.99  Cathy Erway, a noted New York based chef, auth...
# 17   19.99  Learn Effective Source Control Management with...
# 18   24.99  Learn Adobe InDesign with design expert Joseph...
# 19   34.99           Fundamental High School chemistry Part 1
#
#     num_subscribers  avg_rating  num_reviews  num_comments  num_lectures  \
# 0            2231.0    3.750000        134.0          42.0          37.0
# 1           26474.0    4.500000        709.0         112.0           9.0
# 2            1713.0    4.400000         41.0          13.0          14.0
# 3            4988.0    4.800000        395.0          88.0          36.0
# 4            1266.0    4.750000         38.0          12.0          38.0
# 5           20505.0    4.530120        796.0         135.0          31.0
# 6            3309.0    3.850000        958.0         241.0           8.0
# 7           28824.0    4.000000        741.0         189.0          56.0
# 8           10761.0    3.900000        349.0         101.0          87.0
# 9             483.0    4.650000        100.0          45.0          73.0
# 10            794.0    4.100000         27.0          16.0          10.0
# 11           1322.0    4.450000        196.0          76.0           5.0
# 12           2058.0    3.650000         25.0           8.0          81.0
# 13           4454.0    4.350000        829.0         147.0         230.0
# 14           9714.0    4.408389       1081.0         194.0          48.0
# 15           5566.0    4.166666        720.0         163.0           6.0
# 16            505.0    3.250000         24.0           3.0          19.0
# 17            296.0    3.750000         13.0           8.0          31.0
# 18           2069.0    4.100000        172.0          63.0          53.0
# 19             11.0    0.000000          0.0           0.0           8.0
#
#     content_length_min        published_time last_update_date  \
# 0               1268.0  2010-08-05T22:06:13Z       2020-11-06
# 1                 88.0  2010-01-12T18:09:46Z              NaN
# 2                 82.0  2010-10-13T18:07:17Z       2019-10-09
# 3               1511.0  2011-06-20T20:08:38Z       2016-01-13
# 4                569.0  2011-06-23T18:31:20Z              NaN
# 5               1163.0  2011-07-15T04:13:24Z       2018-05-22
# 6                 80.0  2010-04-14T16:32:46Z       2019-03-07
# 7                363.0  2011-07-08T21:32:55Z       2022-09-26
# 8                526.0  2011-07-06T14:06:34Z       2020-11-22
# 9                373.0  2012-07-03T17:03:28Z       2020-02-28
# 10               236.0  2011-07-12T04:11:59Z              NaN
# 11               140.0  2012-09-12T23:47:03Z              NaN
# 12               459.0  2011-07-06T23:45:18Z       2017-01-09
# 13              1813.0  2011-07-23T23:43:34Z       2017-10-21
# 14               183.0  2011-07-09T05:43:31Z       2020-10-03
# 15               158.0  2011-07-11T06:29:02Z              NaN
# 16               148.0  2011-07-18T23:54:24Z              NaN
# 17               454.0  2011-07-29T20:24:56Z              NaN
# 18               359.0  2011-07-29T10:08:39Z       2013-02-28
# 19               152.0  2011-07-18T06:54:02Z       2022-05-12
#
#                 category                 subcategory            topic  \
# 0              Lifestyle             Food & Beverage    Vegan Cooking
# 1               Business            Entrepreneurship     Lean Startup
# 2              Lifestyle             Other Lifestyle    Vegan Cooking
# 3              Lifestyle         Pet Care & Training     Pet Training
# 4                 Design                  Web Design       Web Design
# 5       Health & Fitness                        Yoga             Yoga
# 6   Finance & Accounting         Investing & Trading    Swing Trading
# 7            Development       Programming Languages             Ruby
# 8               Business                       Media       Demo Video
# 9              Marketing  Search Engine Optimization              SEO
# 10  Teaching & Academics            Teacher Training   MBA Admissions
# 11      Health & Fitness                        Yoga        Kundalini
# 12           Development          Mobile Development  iOS Development
# 13         IT & Software           IT Certifications  CCNP Enterprise
# 14           Development             Web Development       JavaScript
# 15              Business            Entrepreneurship     Lean Startup
# 16             Lifestyle             Food & Beverage          Cooking
# 17           Development  Software Development Tools              Git
# 18                Design                Design Tools         InDesign
# 19  Teaching & Academics                     Science        Chemistry
#
#    language                                         course_url  \
# 0   English           /course/vegan-vegetarian-cooking-school/
# 1   English  /course/the-lean-startup-debunking-myths-of-en...
# 2   English  /course/see-my-personal-motivation-for-becomin...
# 3   English                /course/complete-dunbar-collection/
# 4   English             /course/web-design-from-the-ground-up/
# 5   English  /course/yoga-for-weight-loss-and-core-strength...
# 6   English            /course/swing-trading-the-stock-market/
# 7   English  /course/learn-ruby-programming-in-ten-easy-steps/
# 8   English         /course/how-to-create-awesome-demo-videos/
# 9   Spanish  /course/curso-de-posicionamiento-en-buscadores...
# 10  English                           /course/business-school/
# 11  English  /course/kundalini-yoga-to-heal-stress-and-anxi...
# 12  English  /course/beginners-guide-to-iphone-ipad-app-cre...
# 13  English      /course/ccnp-route-on-demand-video-boot-camp/
# 14  English                      /course/beginning-javascript/
# 15  English                          /course/the-lean-startup/
# 16  English              /course/healthy-cooking-fundamentals/
# 17  English             /course/git-in-theory-and-in-practice/
# 18  English                   /course/intro-to-adobe-indesign/
# 19  English  /course/chemistry-funda-from-basics-to-pre-uni...
#
#                 instructor_name                instructor_url
# 0                   Angela Poch             /user/angelapoch/
# 1                     Eric Ries               /user/ericries/
# 2                   Angela Poch             /user/angelapoch/
# 3                    Ian Dunbar             /user/ian-dunbar/
# 4                E Learning Lab            /user/edwin-ang-2/
# 5                 Sadie Nardini           /user/sadienardini/
# 6                    Tom Watson              /user/tomwatson/
# 7             Huw Collingbourne       /user/huwcollingbourne/
# 8              Miguel Hernandez        /user/miguelhernandez/
# 9               Juan Jose Ramos           /user/juanjo-ramos/
# 10  Clear Admit & Beat The GMAT  /user/clearadmitbeatthegmat/
# 11             Valinda Cochella             /user/viriamkaur/
# 12              Infinite Skills         /user/infiniteskills/
# 13                 Chris Bryant            /user/chrisbryant/
# 14         Dollar Design School            /user/marklassoff/
# 15                    Eric Ries               /user/ericries/
# 16                  Cathy Erway            /user/cathyerway2/
# 17               Tony Hillerson          /user/tonyhillerson/
# 18               Joseph Caserto         /user/josephcaserto2/
# 19               Dr Anup Sharma             /user/anupsharma/

# %%
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209734 entries, 0 to 209733
# Data columns (total 20 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  209734 non-null  float64
#  1   title               209734 non-null  object
#  2   is_paid             209734 non-null  bool
#  3   price               209734 non-null  float64
#  4   headline            209703 non-null  object
#  5   num_subscribers     209734 non-null  float64
#  6   avg_rating          209734 non-null  float64
#  7   num_reviews         209734 non-null  float64
#  8   num_comments        209734 non-null  float64
#  9   num_lectures        209734 non-null  float64
#  10  content_length_min  209734 non-null  float64
#  11  published_time      209734 non-null  object
#  12  last_update_date    209597 non-null  object
#  13  category            209734 non-null  object
#  14  subcategory         209734 non-null  object
#  15  topic               208776 non-null  object
#  16  language            209734 non-null  object
#  17  course_url          209734 non-null  object
#  18  instructor_name     209729 non-null  object
#  19  instructor_url      209307 non-null  object
# dtypes: bool(1), float64(8), object(11)
# memory usage: 30.6+ MB
# None

# %%
# display summary statistics of the numerical columns
display(df.describe())
# Out:
#                  id          price  num_subscribers     avg_rating  \
# count  2.097340e+05  209734.000000     2.097340e+05  209734.000000
# mean   3.015403e+06      81.665529     3.096992e+03       3.747179
# std    1.342558e+06     117.317846     1.558132e+04       1.533711
# min    1.769000e+03       0.000000     0.000000e+00       0.000000
# 25%    1.950734e+06      19.990000     2.600000e+01       3.800000
# 50%    3.292863e+06      34.990000     2.060000e+02       4.333334
# 75%    4.189458e+06      99.990000     1.435000e+03       4.625000
# max    4.914146e+06     999.990000     1.752364e+06       5.000000
#
#          num_reviews   num_comments   num_lectures  content_length_min
# count  209734.000000  209734.000000  209734.000000       209734.000000
# mean      244.358812      44.874589      36.548395          265.558856
# std      2458.098276     355.773107      51.871962          454.448676
# min         0.000000       0.000000       0.000000            0.000000
# 25%         3.000000       1.000000      11.000000           69.000000
# 50%        17.000000       5.000000      22.000000          133.000000
# 75%        74.000000      18.000000      42.000000          289.000000
# max    436457.000000   39040.000000    1095.000000        22570.000000

# %% [markdown]
# ## Data Cleaning
# ### Convert data types

# %%
# convert date columns to datetime data type
df['published_time'] = pd.to_datetime(df['published_time'])
df['last_update_date'] = pd.to_datetime(df['last_update_date'], errors='coerce')

# %%
# convert columns to integers
numeric_columns = ['id', 'num_subscribers', 'num_reviews', 'num_comments', 'num_lectures', 'content_length_min']
df[numeric_columns] = df[numeric_columns].astype(int)
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209734 entries, 0 to 209733
# Data columns (total 20 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  209734 non-null  int64
#  1   title               209734 non-null  object
#  2   is_paid             209734 non-null  bool
#  3   price               209734 non-null  float64
#  4   headline            209703 non-null  object
#  5   num_subscribers     209734 non-null  int64
#  6   avg_rating          209734 non-null  float64
#  7   num_reviews         209734 non-null  int64
#  8   num_comments        209734 non-null  int64
#  9   num_lectures        209734 non-null  int64
#  10  content_length_min  209734 non-null  int64
#  11  published_time      209734 non-null  datetime64[ns, UTC]
#  12  last_update_date    209597 non-null  datetime64[ns]
#  13  category            209734 non-null  object
#  14  subcategory         209734 non-null  object
#  15  topic               208776 non-null  object
#  16  language            209734 non-null  object
#  17  course_url          209734 non-null  object
#  18  instructor_name     209729 non-null  object
#  19  instructor_url      209307 non-null  object
# dtypes: bool(1), datetime64[ns, UTC](1), datetime64[ns](1), float64(2), int64(6), object(9)
# memory usage: 30.6+ MB
# None

# %% [markdown]
# ### Missing Values and Duplicates

# %%
# check for missing values in each column
display(df.isnull().sum())
# Out:
# id                      0
# title                   0
# is_paid                 0
# price                   0
# headline               31
# num_subscribers         0
# avg_rating              0
# num_reviews             0
# num_comments            0
# num_lectures            0
# content_length_min      0
# published_time          0
# last_update_date      137
# category                0
# subcategory             0
# topic                 958
# language                0
# course_url              0
# instructor_name         5
# instructor_url        427
# dtype: int64

# %%
# replace missing dates in last_update_date with published_time
df['last_update_date'].fillna(df['published_time'], inplace=True)
display(df.isnull().sum())
# Out:
# id                      0
# title                   0
# is_paid                 0
# price                   0
# headline               31
# num_subscribers         0
# avg_rating              0
# num_reviews             0
# num_comments            0
# num_lectures            0
# content_length_min      0
# published_time          0
# last_update_date        0
# category                0
# subcategory             0
# topic                 958
# language                0
# course_url              0
# instructor_name         5
# instructor_url        427
# dtype: int64

# %%
display(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# <b>Conclusion</b>
# We decided to delete `headline`, `last_update_date`, `topic`, `instructor_name`, `instructor_url`
#
#
# <a href="#Table-of-Contents">Back to top<a/>

# %% [markdown]
# ## EDA
